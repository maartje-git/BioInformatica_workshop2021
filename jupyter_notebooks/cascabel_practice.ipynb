# %% [markdown]
# # Bioinformatics Workshop 2021
# ### Command_line_S1_practice
# #### Maartje Brouwer
# #### 2021 Feb 04
# ###### This notebook is running Python 3.6.7

# %% [markdown]
# #### Cascabel practice

# %%
## 1. Navigate to the BlackSea13 project under your user workshop dedicated directory
# %cd /export/lv3/scratch/workshop_2021/Users/maartje/BlackSea_2013
# Out:
# /export/lv3/scratch/workshop_2021/Users/maartje/BlackSea_2013

# %%
## 2. Setup Cascabel 
#You can copy it from /export/data01/pipelines/CASCABEL
! cp -r /export/data01/pipelines/CASCABEL/ .
# cp -r copies an entire directory. the dot indicates copy in the current directory

## or clone it from GitHub
# git clone https://github/AlejandroAb/CASCABEL.git

# %%
# Go to CASCABEL directory
# %cd CASCABEL
# Out:
# /export/lv3/scratch/workshop_2021/Users/maartje/BlackSea_2013/CASCABEL

# %% [markdown]
# ##### background info
# We are going to work with a subset of 200,000 reads with amplicon data from the Black Sea cruise. There are two different datasets belonging to the same samples, but PCR amplified with different primers:
# •	NIOZ101 -18S
# o	Paired end – 2 x 300
# o	FW Primer: GCTTGTCTCAAAGATTAAGCC
# o	RV Primer: CCTGCTGCCTTCCTTRGA
# •	NIOZ102 -16S
# o	Paired end – 2x300
# o	FW Primer: GTGYCAGCMGCCGCGGTAA
# o	RV Primer: GGACTACNVGGGTWTCTAAT
# Select one of these two datasets to continue working for downstream steps.
#
# ###### I chose 18S for now, because it has unique barcodes on both forward and reverse

# %%
## 3. Activate Cascabel dependencies
# at ada
! source ~/.bashrc.conda3
! source activate qiime1
! export PATH=$PATH:/opt/biolinux/anaconda3/bin
! module load R/4.0.3
! unset LD_PRELOAD

# at YMGA
# ! source  ~/.zshrc.conda344
# Out:
# Anaconda is now active on server ada with base /opt/biolinux/anaconda3          python version : 3.6.7.final.0
# Run "conda deactivate" command to deactivate and exit current python environment

# %% [markdown]
# ##### Configuration files
# As you can see, there are different configuration files on the CASCABEL directory. These configuration files, are already preconfigured for some specific workflows
#
# config.asv.double_bc.yaml  ASV workflow for paired end data
#
# config.asv.double_bc.unpaired.yaml ASV workflow for paired end data and “unpaired” reads.
#
# config.asv.single_bc.yaml ASV workflow for single end data
#
# config.otu.double_bc.yaml OTU workflow for paired end data
#
# config.otu.double_bc.unpaired.yaml OTU workflow for paired end data and “unpaired” reads.

# %% [markdown]
# #### 4. set-up a run for an OTU workflow using accordingly the dataset of your choice (I chose 18S)
# Couldn't do this in Jupyter, but this is what I did in the terminal (MobaXterm)
#
# ! nano config.otu.double_bc.yaml
#
# ##### Changed the following
#
# PROJECT: "BlackSea"
#
# LIBRARY: ["NIOZ101"]
#
# RUN: "Workshop_Test"
#
# interactive : "T"
#
# fw_reads: "/export/lv3/scratch/workshop_2021/Users/maartje/BlackSea_2013/Data/RawData/NIOZ101_1.fastq"
# rv_reads: "/export/lv3/scratch/workshop_2021/Users/maartje/BlackSea_2013/Data/RawData/NIOZ101_2.fastq"
# metadata: "/export/lv3/scratch/workshop_2021/Users/maartje/BlackSea_2013/ProjectInfo/NIOZ101/NIOZ101_18S_blackSea.txt"
# #OR
# input_files: ""
#
# demultiplex: "T"
# create_fastq_files: "T"
# remove_bc: 12                                    # removes only the barcode
# ....
# remove: "T"                                      # removes the primer
# fw_primer: "GTGYCAGCMGCCGCGGTAA"
# rv_primer: "GGACTACNVGGGTWTCTAAT"
# min_overlap: "15"
# extra_params: " --match-read-wildcards"
#
# #The script for splitting the libraries tries to identify the correct Fastq file encoding (phred quality score) using information of the fastq file header. If this information is missing the script can fail. So make sure to include the correct phred offset (33)
# split:
#   q: "19"
#   r: "5"
#   barcode_type:  "24"
#   extra_params: "--phred_offset 33"
#
# #Remove the primers using the cutadapt option match the wild cards on the primers and set a minimum overlap for the adapters to be found at 20 bp.
# cutAdapters: "T"
# cutadapt:
#   command: "cutadapt"
#   adapters: "-g GCTTGTCTCAAAGATTAAGCC...CCTGCTGCCTTCCTTRGA"
#   extra_params: "--match-read-wildcards  -O 20"
# #Important. Notice that the primers removed with the demultiplexing rule is applied only to create individual fastq files per sample, useful for uploading reads to public repositories and also is the input for dada2. While this rule is applied at a different stage for the OTU workflow.
#
# #Select vsearch as the taxonomy assignation method and select a database
# Find the available databases at: http://redmine.nioz.nl/projects/pipeline-for-amplicon-analysis/wiki/Run#9-Databases.
# For 515F_926R primers we recommend to use silva 138 for 515F-806R region
# For F04_R22mod we recommend to use silva r138 for full-length sequences (you can also try other database like the protist ribosomal database).
# assignTaxonomy:
#   tool: "vsearch"
# …
# vsearch:
#    command: "vsearch"
#    db_file: "/export/data01/databases/silva/qiime/SILVA_138_QIIME_release/sil$
#    mapFile: "/export/data01/databases/silva/qiime/SILVA_138_QIIME_release/sil$
#    identity: 0.8
#
# #We don’t want to align the sequences for the moment so skip the alignment for the representative sequences
# alignRep:
#   align: "F"
#
# #Filter observations (OTUs) from the OTU table with a minimum abundance of 5 and present at least on 2 different samples
# filterOtu:
#   n: "5"                                         # minimum abundance
#   extra_params: "-s 2"                           # at least on 2 samples
#
# ###### In nano you can search patterns with ctrl + w
# ###### Save the file Ctrl + o (give it a new name, tell it yes as a different file)
# Saved as config.otu_swarm.double_bc.N101.yaml
# ###### Exit nano with Ctrl + x

# %%
## 5. Create the directed acyclic graph (DAG) of the entire pipeline
# Send it to a svg file called OTU_WF_<clustering_method>.svg 
! snakemake --configfile config.otu_swarm.double_bc.NIOZ101.yaml --dag | dot -Tsvg > OTU_WF_swarm.svg 
# A DAG is a visual representation of the entire pipeline that will be run.

# %%
## 6. make a dry-run to see the commands and the number of rules that are going to be executed.
! snakemake --configfile config.otu_swarm.double_bc.NIOZ101.yaml -np
# -ng makes it a dry-run, so you can check all steps. If everything is fine, repeat without -ng
## 7. The execution plan contains 65 rules (see bottom line)
# Out:
# rule init_structure:
#     input: /export/lv3/scratch/workshop_2021/Users/maartje/BlackSea_2013/Data/RawData/NIOZ101_1.fastq, /export/lv3/scratch/workshop_2021/Users/maartje/BlackSea_2013/Data/RawData/NIOZ101_2.fastq, /export/lv3/scratch/workshop_2021/Users/maartje/BlackSea_2013/ProjectInfo/NIOZ101/NIOZ101_18S_blackSea.txt
#     output: BlackSea/samples/NIOZ101/rawdata/fw.fastq, BlackSea/samples/NIOZ101/rawdata/rv.fastq, BlackSea/metadata/sampleList_mergedBarcodes_NIOZ101.txt
#     jobid: 31
#     wildcards: PROJECT=BlackSea, sample=NIOZ101
#
# Scripts/init_sample.sh BlackSea NIOZ101 /export/lv3/scratch/workshop_2021/Users/maartje/BlackSea_2013/ProjectInfo/NIOZ101/NIOZ101_18S_blackSea.txt /export/lv3/scratch/workshop_2021/Users/maartje/BlackSea_2013/Data/RawData/NIOZ101_1.fastq /export/lv3/scratch/workshop_2021/Users/maartje/BlackSea_2013/Data/RawData/NIOZ101_2.fastq
#
# rule fast_qc:
#     input: BlackSea/samples/NIOZ101/rawdata/fw.fastq, BlackSea/samples/NIOZ101/rawdata/rv.fastq
#     output: BlackSea/samples/NIOZ101/qc/fw_fastqc.html, BlackSea/samples/NIOZ101/qc/rv_fastqc.html, BlackSea/samples/NIOZ101/qc/fw_fastqc/summary.txt, BlackSea/samples/NIOZ101/qc/rv_fastqc/summary.txt
#     jobid: 64
#     benchmark: BlackSea/samples/NIOZ101/qc/fq.benchmark
#     wildcards: PROJECT=BlackSea, sample=NIOZ101
#
# fastqc BlackSea/samples/NIOZ101/rawdata/fw.fastq BlackSea/samples/NIOZ101/rawdata/rv.fastq --extract  -o BlackSea/samples/NIOZ101/qc/
#
# rule validateQC:
#     input: BlackSea/samples/NIOZ101/qc/fw_fastqc/summary.txt, BlackSea/samples/NIOZ101/qc/rv_fastqc/summary.txt, BlackSea/samples/NIOZ101/qc/fw_fastqc.html, BlackSea/samples/NIOZ101/qc/rv_fastqc.html, BlackSea/samples/NIOZ101/rawdata/fw.fastq, BlackSea/samples/NIOZ101/rawdata/rv.fastq
#     output: BlackSea/samples/NIOZ101/qc/fq_fw_internal_validation.txt, BlackSea/samples/NIOZ101/qc/fq_rv_internal_validation.txt
#     jobid: 63
#     wildcards: PROJECT=BlackSea, sample=NIOZ101
#
#
# rule pear:
#     input: BlackSea/samples/NIOZ101/rawdata/fw.fastq, BlackSea/samples/NIOZ101/rawdata/rv.fastq, BlackSea/samples/NIOZ101/qc/fq_fw_internal_validation.txt, BlackSea/samples/NIOZ101/qc/fq_rv_internal_validation.txt
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.fastq, BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.forward.fastq, BlackSea/runs/Workshop_Test/NIOZ101_data/peared/pear.log, BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.reverse.fastq
#     jobid: 59
#     benchmark: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/pear.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# pear -f BlackSea/samples/NIOZ101/rawdata/fw.fastq -r BlackSea/samples/NIOZ101/rawdata/rv.fastq -o BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs -t 100 -v 10 -j 6 -p 0.05  > BlackSea/runs/Workshop_Test/NIOZ101_data/peared/pear.log
#
# rule identify_unpaired_fw:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.forward.fastq
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.forward.out
#     jobid: 57
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# cat BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.forward.fastq | awk '{if((NR-1)%4==0){header=$1}else if((NR-2)%4==0){seq=$0}else if(NR%4==0){print header"\t"seq"\t"$0}}' > BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.forward.out
#
# rule identify_unpaired_rv:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.reverse.fastq
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.reverse.out
#     jobid: 56
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# cat BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.reverse.fastq | awk '{if((NR-1)%4==0){header=$1}else if((NR-2)%4==0){seq=$0}else if(NR%4==0){print header"\t"seq"\t"$0}}' > BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.reverse.out
#
# rule pair_unpaired:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.forward.out, BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.reverse.out
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.UNPAIRED.fastq
#     jobid: 61
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# cat BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.forward.out | awk -v ch="T" 'BEGIN{for(i=1;i<=length(ch);i++){chq=chq "G"}} NR==FNR{seqs[$1]=$2;qa[$1]=$3;next}{print $1"\n"seqs[$1] ch $2"\n+\n"qa[$1] chq $3}' - BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.reverse.out > BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.UNPAIRED.fastq
#
# rule fastQCPear:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.fastq
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/qc/seqs.assembled_fastqc.html, BlackSea/runs/Workshop_Test/NIOZ101_data/peared/qc/seqs.assembled_fastqc/summary.txt
#     jobid: 60
#     benchmark: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/qc/fq.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# fastqc BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.fastq --extract -o BlackSea/runs/Workshop_Test/NIOZ101_data/peared/qc/
#
# rule bc_mapping_validation:
#     input: BlackSea/metadata/sampleList_mergedBarcodes_NIOZ101.txt
#     output: BlackSea/metadata/bc_validation/NIOZ101/sampleList_mergedBarcodes_NIOZ101.log
#     jobid: 58
#     benchmark: BlackSea/metadata/bc_validation/NIOZ101/validation.benchmark
#     wildcards: PROJECT=BlackSea, sample=NIOZ101
#
# validate_mapping_file.py -o BlackSea/metadata/bc_validation/NIOZ101/ -m BlackSea/metadata/sampleList_mergedBarcodes_NIOZ101.txt
#
# rule concat_assembly:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.fastq, BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.UNPAIRED.fastq
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.PAIRED_UNPAIRED.fastq
#     jobid: 54
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# cat BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.fastq BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.UNPAIRED.fastq > BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.PAIRED_UNPAIRED.fastq
#
# rule validatePear:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/pear.log
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/pear.log.validation
#     jobid: 52
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
#
# rule validateBCV:
#     input: BlackSea/metadata/bc_validation/NIOZ101/sampleList_mergedBarcodes_NIOZ101.log, BlackSea/metadata/sampleList_mergedBarcodes_NIOZ101.txt
#     output: BlackSea/metadata/bc_validation/NIOZ101/validation.log
#     jobid: 51
#     wildcards: PROJECT=BlackSea, sample=NIOZ101
#
#
# rule validateFastQCPear:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/qc/seqs.assembled_fastqc/summary.txt, BlackSea/runs/Workshop_Test/NIOZ101_data/peared/qc/seqs.assembled_fastqc.html, BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.fastq
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/qc/fq_fw_internal_validation.txt
#     jobid: 53
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
#
# rule extract_barcodes:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/peared/pear.log.validation, BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.PAIRED_UNPAIRED.fastq, BlackSea/runs/Workshop_Test/NIOZ101_data/peared/qc/fq_fw_internal_validation.txt, BlackSea/metadata/bc_validation/NIOZ101/validation.log
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes/barcodes.fastq, BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes/reads.fastq
#     jobid: 43
#     benchmark: BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes/barcodes.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# extract_barcodes.py -f BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.PAIRED_UNPAIRED.fastq -c barcode_paired_stitched --bc1_len 12 --bc2_len 12  -o BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes/
#
# rule correct_barcodes:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes/barcodes.fastq, BlackSea/metadata/sampleList_mergedBarcodes_NIOZ101.txt
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes/barcodes.fastq_corrected
#     jobid: 42
#     benchmark: BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes/barcodes_corrected.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# java -cp Scripts/BarcodeCorrector/build/classes/ barcodecorrector.BarcodeCorrector -f BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes/barcodes.fastq -b  BlackSea/metadata/sampleList_mergedBarcodes_NIOZ101.txt -m  2
#
# rule split_libraries:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes/reads.fastq, BlackSea/metadata/sampleList_mergedBarcodes_NIOZ101.txt, BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes/barcodes.fastq_corrected
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.fna, BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/split_library_log.txt
#     jobid: 36
#     benchmark: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/splitLibs.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# split_libraries_fastq.py -m BlackSea/metadata/sampleList_mergedBarcodes_NIOZ101.txt -i BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes/reads.fastq -o BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs -b BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes/barcodes.fastq_corrected -q 19 -r 5 --retain_unassigned_reads --barcode_type 24 --phred_offset 33
#
# rule get_unassigned:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.fna, BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.PAIRED_UNPAIRED.fastq
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/unassigned.fastq
#     jobid: 62
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# cat BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.fna | grep "^>Unassigned" |  sed 's/>Unassigned_[0-9]* /@/g' | sed 's/ .*//' | grep -F -w -A3  -f - BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.assembled.PAIRED_UNPAIRED.fastq |  sed '/^--$/d' > BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/unassigned.fastq
#
# rule rc_unassigned:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/unassigned.fastq
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/unassigned.reversed.fastq
#     jobid: 55
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# vsearch --fastx_revcomp BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/unassigned.fastq --fastqout BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/unassigned.reversed.fastq
#
# rule extract_barcodes_unassigned:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/unassigned.reversed.fastq
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes_unassigned/barcodes.fastq, BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes_unassigned/reads.fastq
#     jobid: 45
#     benchmark: BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes_unassigned/barcodes.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# extract_barcodes.py -f BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/unassigned.reversed.fastq -c barcode_paired_stitched --bc1_len 12 --bc2_len 12  -o BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes_unassigned/
#
# rule remove_unassigned_fw:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.fna
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.no_unassigneds.fna
#     jobid: 30
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# cat BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.fna | grep -P -A1 '(?!>Unass)^>' | sed '/^--$/d' > BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.no_unassigneds.fna
#
# rule find_unassembled_fw_ids:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.no_unassigneds.fna, BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.forward.out
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.unassembled_ids.txt
#     jobid: 50
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# cat BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.forward.out | cut -f1 | sed 's/@//' | grep -F -w -f - BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.no_unassigneds.fna | cut -f1 -d" " | sed 's/>//' > BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.unassembled_ids.txt || true
#
# rule remove_unassembled_fw:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.no_unassigneds.fna, BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.unassembled_ids.txt
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.assigned.fna
#     jobid: 41
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# filter_fasta.py -f BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.no_unassigneds.fna -s BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.unassembled_ids.txt -n -o BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.assigned.fna
#
# rule correct_barcodes_unassigned:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes_unassigned/barcodes.fastq, BlackSea/metadata/sampleList_mergedBarcodes_NIOZ101.txt
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes_unassigned/barcodes.fastq_corrected
#     jobid: 44
#     benchmark: BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes_unassigned/barcodes_corrected.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# java -cp Scripts/BarcodeCorrector/build/classes/ barcodecorrector.BarcodeCorrector -f BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes_unassigned/barcodes.fastq -b  BlackSea/metadata/sampleList_mergedBarcodes_NIOZ101.txt -m  2
#
# rule split_libraries_rc:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.fna, BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes_unassigned/reads.fastq, BlackSea/metadata/sampleList_mergedBarcodes_NIOZ101.txt, BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes_unassigned/barcodes.fastq_corrected
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.fna, BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/split_library_log.txt
#     jobid: 37
#     benchmark: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/splitLibs.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
#
# rule remove_unassigned_rv:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.fna
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.no_unassigneds.fna
#     jobid: 32
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# cat BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.fna | grep -P -A1 '(?!>Unass)^>' | sed '/^--$/d' > BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.no_unassigneds.fna
#
# rule find_unassembled_rv_ids:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.no_unassigneds.fna, BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.reverse.out
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.unassembled_ids.txt
#     jobid: 48
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# cat BlackSea/runs/Workshop_Test/NIOZ101_data/peared/seqs.unassembled.reverse.out | cut -f1 | sed 's/@//' | grep -F -w -f - BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.no_unassigneds.fna | cut -f1 -d" " | sed 's/>//' > BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.unassembled_ids.txt || true
#
# rule remove_unassembled_rv:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.no_unassigneds.fna, BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.unassembled_ids.txt
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.assigned.fna
#     jobid: 39
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# filter_fasta.py -f BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.no_unassigneds.fna -s BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.unassembled_ids.txt -n -o BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.assigned.fna
#
# rule create_unassigned_file:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.fna
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/seqs.unassigned.fna
#     jobid: 49
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# cat BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.fna | grep -A1 --no-group-separator "^>Unassigned"  > BlackSea/runs/Workshop_Test/NIOZ101_data/seqs.unassigned.fna
#
# rule validateDemultiplex:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.assigned.fna, BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.assigned.fna, BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/split_library_log.txt, BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/split_library_log.txt, BlackSea/runs/Workshop_Test/NIOZ101_data/barcodes/reads.fastq, BlackSea/runs/Workshop_Test/NIOZ101_data/seqs.unassigned.fna
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/split_library_log.txt.validation
#     jobid: 40
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
#
# rule combine_accepted_reads:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.assigned.fna, BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.assigned.fna, BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/split_library_log.txt.validation
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_accepted.fna
#     jobid: 35
#     benchmark: BlackSea/runs/Workshop_Test/NIOZ101_data/combine_seqs_fw_rev.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# cat BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.assigned.fna BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.assigned.fna  > BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_accepted.fna
#
# rule cutadapt:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_accepted.fna
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_accepted_no_adapters.fna, BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_accepted_no_adapters.log
#     jobid: 28
#     benchmark: BlackSea/runs/Workshop_Test/NIOZ101_data/cutadapt.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# cutadapt -f fasta -g GCTTGTCTCAAAGATTAAGCC...CCTGCTGCCTTCCTTRGA --match-read-wildcards  -O 20 -o BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_accepted_no_adapters.fna BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_accepted.fna  > BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_accepted_no_adapters.log
#
# rule histogram:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_accepted_no_adapters.fna
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_accepted_lengths.txt, BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_accepted_hist.txt
#     jobid: 29
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# cat BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_accepted_no_adapters.fna | grep -v '^>' | awk '{print length}' > BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_accepted_lengths.txt &&  sort -g BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_accepted_lengths.txt | uniq -c > BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_accepted_hist.txt
#
# rule histogram_chart:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_accepted_hist.txt, BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_accepted_lengths.txt
#     output: BlackSea/runs/Workshop_Test/report_files/seqs_dist_hist.NIOZ101.png, BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_statistics.txt
#     jobid: 27
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# Rscript Scripts/histogram.R $PWD BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_accepted_hist.txt BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_accepted_lengths.txt BlackSea/runs/Workshop_Test/NIOZ101_data/ BlackSea/runs/Workshop_Test/report_files/seqs_dist_hist.NIOZ101.png
#
# rule remove_short_long_reads:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_statistics.txt, BlackSea/runs/Workshop_Test/report_files/seqs_dist_hist.NIOZ101.png, BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_accepted_hist.txt, BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_accepted_no_adapters.fna
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_filtered.fasta, BlackSea/runs/Workshop_Test/NIOZ101_data/filter.log
#     jobid: 20
#     benchmark: BlackSea/runs/Workshop_Test/NIOZ101_data/filter.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
#
# rule combine_filtered_samples:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_filtered.fasta
#     output: BlackSea/runs/Workshop_Test/seqs_fw_rev_combined.fasta, BlackSea/runs/Workshop_Test/samples.log
#     jobid: 12
#     benchmark: BlackSea/runs/Workshop_Test/combine_seqs_fw_rev.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
#
# rule dereplicate:
#     input: BlackSea/runs/Workshop_Test/seqs_fw_rev_combined.fasta
#     output: BlackSea/runs/Workshop_Test/derep/seqs_fw_rev_combined_derep.fasta, BlackSea/runs/Workshop_Test/derep/seqs_fw_rev_combined_derep.uc
#     jobid: 34
#     benchmark: BlackSea/runs/Workshop_Test/derep/derep.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# vsearch --derep_fulllength BlackSea/runs/Workshop_Test/seqs_fw_rev_combined.fasta --output BlackSea/runs/Workshop_Test/derep/seqs_fw_rev_combined_derep.fasta --uc BlackSea/runs/Workshop_Test/derep/seqs_fw_rev_combined_derep.uc --strand both --fasta_width 0 --minuniquesize 1
#
# rule cluster_OTUs:
#     input: BlackSea/runs/Workshop_Test/derep/seqs_fw_rev_combined_derep.fasta
#     output: BlackSea/runs/Workshop_Test/otu/seqs_fw_rev_combined_derep_otus.txt
#     jobid: 26
#     benchmark: BlackSea/runs/Workshop_Test/otu.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# pick_otus.py -m uclust -i BlackSea/runs/Workshop_Test/derep/seqs_fw_rev_combined_derep.fasta -o BlackSea/runs/Workshop_Test/otu/  -s 0.97 --threads 6
#
# rule pick_representatives:
#     input: BlackSea/runs/Workshop_Test/otu/seqs_fw_rev_combined_derep_otus.txt, BlackSea/runs/Workshop_Test/seqs_fw_rev_combined.fasta
#     output: BlackSea/runs/Workshop_Test/otu/representative_seq_set.fasta, BlackSea/runs/Workshop_Test/otu/representative_seq_set.log
#     jobid: 19
#     benchmark: BlackSea/runs/Workshop_Test/pick_reps.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# pick_rep_set.py -m most_abundant -i BlackSea/runs/Workshop_Test/otu/seqs_fw_rev_combined_derep_otus.txt -f BlackSea/runs/Workshop_Test/seqs_fw_rev_combined.fasta -o BlackSea/runs/Workshop_Test/otu/representative_seq_set.fasta --log_fp BlackSea/runs/Workshop_Test/otu/representative_seq_set.log
#
# rule assign_taxonomy:
#     input: BlackSea/runs/Workshop_Test/otu/representative_seq_set.fasta
#     output: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/representative_seq_set_tax_vsearch.out
#     jobid: 47
#     benchmark: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/assign_taxa.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# vsearch  --usearch_global BlackSea/runs/Workshop_Test/otu/representative_seq_set.fasta --db /export/data01/databases/silva/qiime/SILVA_138_QIIME_release/silva-138-99-seqs.fasta --dbmask none --qmask none --rowlen 0 --id 0.8 --iddef 2  --userfields query+id2+target --threads 10 --top_hits_only --maxrejects 32  --maxaccepts 5 --output_no_hits --userout BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/representative_seq_set_tax_vsearch.out
#
# rule mapp_vsearch_taxo:
#     input: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/representative_seq_set_tax_vsearch.out
#     output: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/taxons.txt
#     jobid: 46
#     benchmark: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/assign_taxa.map.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# cat BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/representative_seq_set_tax_vsearch.out  | cut -f3 | sort | uniq | grep -F -w -f -  /export/data01/databases/silva/qiime/SILVA_138_QIIME_release/silva-138-99-seqs.taxonomy.tsv > BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/taxons.txt
#
# rule prepare_vsearch_for_stampa:
#     input: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/taxons.txt, BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/representative_seq_set_tax_vsearch.out
#     output: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/hits.vsearch.out
#     jobid: 38
#     benchmark: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/assign_taxa.hits.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# echo '*\tUnassigned' | cat BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/taxons.txt - | awk 'NR==FNR {h[$1] = $2; next} {print $1"\t"$2"\t"$3" "h[$3]}' FS="\t" - FS="\t" BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/representative_seq_set_tax_vsearch.out  > BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/hits.vsearch.out
#
# rule run_stampa:
#     input: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/hits.vsearch.out
#     output: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/results.vsearch.out
#     jobid: 33
#     benchmark: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/stampa.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# Scripts/stampa_merge.py BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/ ';'
#
# rule normalize_taxo_out:
#     input: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/results.vsearch.out
#     output: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/representative_seq_set_tax_assignments.txt
#     jobid: 24
#     benchmark: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/stampa.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# cat BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/results.vsearch.out |  awk -F"\t" '{print $1"\t"$4"\t"$3"\t"$5}' | sed 's/N;o;_;h;i;t/Unassigned/' > BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/representative_seq_set_tax_assignments.txt
#
# rule remap_clusters:
#     input: BlackSea/runs/Workshop_Test/otu/seqs_fw_rev_combined_derep_otus.txt, BlackSea/runs/Workshop_Test/derep/seqs_fw_rev_combined_derep.uc
#     output: BlackSea/runs/Workshop_Test/otu/seqs_fw_rev_combined_remapped_otus.txt, BlackSea/runs/Workshop_Test/otu/remap.log
#     jobid: 25
#     benchmark: BlackSea/runs/Workshop_Test/derep/remap.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# java -cp Scripts/ClusterMapper/build/classes clustermapper.ClusterMapper uc2otu -uc BlackSea/runs/Workshop_Test/derep/seqs_fw_rev_combined_derep.uc -otu BlackSea/runs/Workshop_Test/otu/seqs_fw_rev_combined_derep_otus.txt -o BlackSea/runs/Workshop_Test/otu/seqs_fw_rev_combined_remapped_otus.txt > BlackSea/runs/Workshop_Test/otu/remap.log
#
# rule make_otu_table:
#     input: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/representative_seq_set_tax_assignments.txt, BlackSea/runs/Workshop_Test/otu/seqs_fw_rev_combined_remapped_otus.txt
#     output: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable.biom
#     jobid: 17
#     benchmark: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable.biom.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# make_otu_table.py -i BlackSea/runs/Workshop_Test/otu/seqs_fw_rev_combined_remapped_otus.txt -t BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/representative_seq_set_tax_assignments.txt -o BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable.biom
#
# rule filter_otu:
#     input: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable.biom
#     output: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable_noSingletons.biom
#     jobid: 18
#     benchmark: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable_nosingletons.bio.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# filter_otus_from_otu_table.py -i BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable.biom -o BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable_noSingletons.biom -n 5 -s 2
#
# rule convert_filter_otu:
#     input: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable_noSingletons.biom
#     output: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable_noSingletons.txt
#     jobid: 14
#     benchmark: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable_nosingletons.txt.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# biom convert -i BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable_noSingletons.biom -o BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable_noSingletons.txt --table-type 'OTU table' --header-key taxonomy --to-tsv
#
# rule filter_rep_seqs:
#     input: BlackSea/runs/Workshop_Test/otu/representative_seq_set.fasta, BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable_noSingletons.biom
#     output: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/representative_seq_set_noSingletons.fasta
#     jobid: 11
#     benchmark: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/representative_seq_set_noSingletons.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# filter_fasta.py -f BlackSea/runs/Workshop_Test/otu/representative_seq_set.fasta -o BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/representative_seq_set_noSingletons.fasta -b BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable_noSingletons.biom
#
# rule krona_report:
#     input: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable_noSingletons.txt
#     output: BlackSea/runs/Workshop_Test/report_files/krona_report.vsearch.html
#     jobid: 9
#     benchmark: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/krona_report.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
#
# rule convert_table:
#     input: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable.biom
#     output: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable.txt
#     jobid: 13
#     benchmark: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable.txt.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# biom convert -i BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable.biom -o BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable.txt --table-type 'OTU table' --header-key taxonomy --to-tsv
#
# rule summarize_taxa:
#     input: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable.biom
#     output: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/summary/otuTable_L6.txt
#     jobid: 8
#     benchmark: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/summary/summarize_taxa.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# summarize_taxa.py -i BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable.biom -o BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/summary/ --level 2,3,4,5,6,7
#
# rule summarize_taxa_no_singletons:
#     input: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable_noSingletons.biom
#     output: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/summary_noSingletons/otuTable_noSingletons_L6.txt
#     jobid: 10
#     benchmark: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/summary/summarize_taxa.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# summarize_taxa.py -i BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable_noSingletons.biom -o BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/summary_noSingletons/ --level 2,3,4,5,6,7
#
# rule report_all:
#     input: BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable.txt, BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/summary/otuTable_L6.txt, BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/otuTable_noSingletons.txt, BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/summary_noSingletons/otuTable_noSingletons_L6.txt, BlackSea/runs/Workshop_Test/otu/taxonomy_vsearch/representative_seq_set_noSingletons.fasta, BlackSea/runs/Workshop_Test/report_files/krona_report.vsearch.html, BlackSea/runs/Workshop_Test/samples.log
#     output: BlackSea/runs/Workshop_Test/reporttmp_all.html
#     jobid: 6
#     benchmark: BlackSea/runs/Workshop_Test/report_all.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
#
# rule tune_report_all:
#     input: BlackSea/runs/Workshop_Test/reporttmp_all.html
#     output: BlackSea/runs/Workshop_Test/otu_report_vsearch.html
#     jobid: 3
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
#
# rule write_dmx_files_fw:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.no_unassigneds.fna, BlackSea/samples/NIOZ101/rawdata/fw.fastq, BlackSea/samples/NIOZ101/rawdata/rv.fastq
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/demultiplexed/summary_fw.txt
#     jobid: 21
#     benchmark: BlackSea/runs/Workshop_Test/NIOZ101_data/demultiplexed/demultiplex_fq.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# java  -cp Scripts DemultiplexQiime --over-write --fasta -a fw -b 24  -d BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibs/seqs.no_unassigneds.fna -o BlackSea/runs/Workshop_Test/NIOZ101_data/demultiplexed/ -r1 BlackSea/samples/NIOZ101/rawdata/fw.fastq -r2 BlackSea/samples/NIOZ101/rawdata/rv.fastq --remove-header
#
# rule write_dmx_files_rv:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.no_unassigneds.fna, BlackSea/runs/Workshop_Test/NIOZ101_data/demultiplexed/summary_fw.txt, BlackSea/samples/NIOZ101/rawdata/fw.fastq, BlackSea/samples/NIOZ101/rawdata/rv.fastq
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/demultiplexed/summary_rv.txt
#     jobid: 22
#     benchmark: BlackSea/runs/Workshop_Test/NIOZ101_data/demultiplexed/demultiplex_fq.benchmark
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# java  -cp Scripts DemultiplexQiime  --fasta -a rv -b 24  -d BlackSea/runs/Workshop_Test/NIOZ101_data/splitLibsRC/seqs.no_unassigneds.fna -o BlackSea/runs/Workshop_Test/NIOZ101_data/demultiplexed/ -r1 BlackSea/samples/NIOZ101/rawdata/rv.fastq -r2 BlackSea/samples/NIOZ101/rawdata/fw.fastq --remove-header
#
# rule count_samples_final:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_filtered.fasta, BlackSea/metadata/sampleList_mergedBarcodes_NIOZ101.txt
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_filtered.dist.txt
#     jobid: 23
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# cat BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_filtered.fasta | grep '^>' |  cut -d'_' -f1 | sed 's/>//g' | sort | uniq -c | sort -nr | awk '{print $1"\t"$2}' | awk 'NR==FNR{h[$2]=$1; next} {print $1"\t"h[$1]}' - BlackSea/metadata/sampleList_mergedBarcodes_NIOZ101.txt | grep -v "#" > BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_filtered.dist.txt
#
# rule distribution_chart:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_filtered.dist.txt
#     output: BlackSea/runs/Workshop_Test/report_files/seqs_fw_rev_filtered.NIOZ101.dist.png
#     jobid: 16
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# python  Scripts/sampleDist.manual.py BlackSea/runs/Workshop_Test/NIOZ101_data/seqs_fw_rev_filtered.dist.txt BlackSea/runs/Workshop_Test/report_files/seqs_fw_rev_filtered.NIOZ101.dist.png
#
# rule remove_primers_dmx_files:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/demultiplexed/summary_fw.txt, BlackSea/runs/Workshop_Test/NIOZ101_data/demultiplexed/summary_rv.txt
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/demultiplexed/summary.txt
#     jobid: 15
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# Scripts/removePrimersDemultiplex.sh BlackSea/runs/Workshop_Test/NIOZ101_data/demultiplexed fastq.gz GTGYCAGCMGCCGCGGTAA GGACTACNVGGGTWTCTAAT 1  --match-read-wildcards
#
# rule report:
#     input: BlackSea/runs/Workshop_Test/otu_report_vsearch.html, BlackSea/runs/Workshop_Test/report_files/seqs_fw_rev_filtered.NIOZ101.dist.png, BlackSea/runs/Workshop_Test/NIOZ101_data/demultiplexed/summary.txt
#     output: BlackSea/runs/Workshop_Test/NIOZ101_data/report.html
#     jobid: 7
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
#
# rule tune_report:
#     input: BlackSea/runs/Workshop_Test/NIOZ101_data/report.html
#     output: BlackSea/runs/Workshop_Test/report_NIOZ101_vsearch.html
#     jobid: 4
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
#
# rule translate_to_pdf:
#     input: BlackSea/runs/Workshop_Test/otu_report_vsearch.html
#     output: BlackSea/runs/Workshop_Test/otu_report_vsearch.pdf
#     jobid: 5
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# wkhtmltopdf -T 10mm -B 30mm   BlackSea/runs/Workshop_Test/otu_report_vsearch.html BlackSea/runs/Workshop_Test/otu_report_vsearch.pdf
#
# rule translate_pdf_final_report:
#     input: BlackSea/runs/Workshop_Test/report_NIOZ101_vsearch.html, BlackSea/runs/Workshop_Test/otu_report_vsearch.pdf
#     output: BlackSea/runs/Workshop_Test/report_NIOZ101_vsearch.pdf
#     jobid: 2
#     wildcards: PROJECT=BlackSea, run=Workshop_Test, sample=NIOZ101
#
# wkhtmltopdf -T 10mm -B 30mm  BlackSea/runs/Workshop_Test/report_NIOZ101_vsearch.html BlackSea/runs/Workshop_Test/report_NIOZ101_vsearch.pdf
#
# rule create_portable_report:
#     input: BlackSea/runs/Workshop_Test/report_NIOZ101_vsearch.html, BlackSea/runs/Workshop_Test/otu_report_vsearch.html
#     output: BlackSea/runs/Workshop_Test/report_vsearch.zip
#     jobid: 1
#     wildcards: PROJECT=BlackSea, run=Workshop_Test
#
# zip -r BlackSea/runs/Workshop_Test/report_vsearch.zip BlackSea/runs/Workshop_Test/report_files BlackSea/runs/Workshop_Test/report_NIOZ101_vsearch.html BlackSea/runs/Workshop_Test/otu_report_vsearch.html
#
# localrule all:
#     input: BlackSea/runs/Workshop_Test/report_NIOZ101_vsearch.pdf, BlackSea/runs/Workshop_Test/report_vsearch.zip
#     jobid: 0
#
# Job counts:
# 	count	jobs
# 	1	all
# 	1	assign_taxonomy
# 	1	bc_mapping_validation
# 	1	cluster_OTUs
# 	1	combine_accepted_reads
# 	1	combine_filtered_samples
# 	1	concat_assembly
# 	1	convert_filter_otu
# 	1	convert_table
# 	1	correct_barcodes
# 	1	correct_barcodes_unassigned
# 	1	count_samples_final
# 	1	create_portable_report
# 	1	create_unassigned_file
# 	1	cutadapt
# 	1	dereplicate
# 	1	distribution_chart
# 	1	extract_barcodes
# 	1	extract_barcodes_unassigned
# 	1	fastQCPear
# 	1	fast_qc
# 	1	filter_otu
# 	1	filter_rep_seqs
# 	1	find_unassembled_fw_ids
# 	1	find_unassembled_rv_ids
# 	1	get_unassigned
# 	1	histogram
# 	1	histogram_chart
# 	1	identify_unpaired_fw
# 	1	identify_unpaired_rv
# 	1	init_structure
# 	1	krona_report
# 	1	make_otu_table
# 	1	mapp_vsearch_taxo
# 	1	normalize_taxo_out
# 	1	pair_unpaired
# 	1	pear
# 	1	pick_representatives
# 	1	prepare_vsearch_for_stampa
# 	1	rc_unassigned
# 	1	remap_clusters
# 	1	remove_primers_dmx_files
# 	1	remove_short_long_reads
# 	1	remove_unassembled_fw
# 	1	remove_unassembled_rv
# 	1	remove_unassigned_fw
# 	1	remove_unassigned_rv
# 	1	report
# 	1	report_all
# 	1	run_stampa
# 	1	split_libraries
# 	1	split_libraries_rc
# 	1	summarize_taxa
# 	1	summarize_taxa_no_singletons
# 	1	translate_pdf_final_report
# 	1	translate_to_pdf
# 	1	tune_report
# 	1	tune_report_all
# 	1	validateBCV
# 	1	validateDemultiplex
# 	1	validateFastQCPear
# 	1	validatePear
# 	1	validateQC
# 	1	write_dmx_files_fw
# 	1	write_dmx_files_rv
# 	65

# %% [markdown]
# ### 8. Run the pipeline
# snakemake --configfile ./CASCABEL/config.otu_swarm.double_bc.NIOZ101.yaml
# Doesn't work through jupyter

# %% [markdown]
# ### First 3 messages during running the pipeline
# something similar to this
# ![image.png](attachment:image.png)
#
# Answered Yes (FastQC is not the best option for QC of amplicon data, we should look for alternatives but haven't had time yet.)

# %% [markdown]
# ### 4th message during running the pipeline
# ![image.png](attachment:image.png)
# Answered Yes (% unassigned reads)

# %% [markdown]
# ### 9. Cascabel will stop at the length filtering step (rule: remove_short_long_reads).
# Print the sequence length histogram
# adjust the minimum and maximum values to include sequences with at least 50 reps according to their length.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 10. Once that your run is finished, locate the report “report_vsearch.zip”
# transfer that file to your computer --> C:\Users\dnalab\Desktop\unix_workshop\Cascabel\report_vsearch.zip
# exit server. go to directory
#
# ! cd /home/mobaxterm/Desktop/unix_workshop/Cascabel
#
# Un-compress the file and inspect the report
#
# ! unzip report_vsearch.zip
